# %% [markdown]
# ![image.png](attachment:2b4bbebb-e001-40f6-bf3b-80f3a2b53233.png)

# %%
# the above shows an example of sIMPLE LINEAR REGREssion
# or say a positive co-relation between faeture vectors
# the above data shows a more of a related data that too with a linear relation

# %% [markdown]
# `the ability of a machine to learn from experience rather than explicitly being coded`
# + when i say `ability of a machine to learn from experience` it means a computer program trying to identify the patterns in a data

# %% [markdown]
# ![image.png](attachment:5a14ab74-95c7-43b3-a783-d197303a0ec1.png)

# %% [markdown]
# + trying to fit a line to data
# + now the question is that perfect fit,
# + there a infinite no of lines which can fit to data to give you some prediction
# + for the the above equation its a simple line` y=Mx+c`

# %% [markdown]
# + `c` from `y=Mx+c` is a constant
# + c=0 which line going through origin, m is the slope

# %% [markdown]
# ![image.png](attachment:ade2200a-b071-42a3-8d0a-fe660a2ee628.png)

# %% [markdown]
# ![image.png](attachment:3f386d7b-b7a5-4d92-a5d3-d4f7256d3ea2.png)

# %%
# one can fit n no of lines to data 
# do i need to predict all from all the line 
# NO
# 'M' decides the orientation and c decides the bias
# we need to find the best m and c values
# best in a sense lowest error

# %% [markdown]
# ![image.png](attachment:e216c4a7-6c7b-4238-b2a6-a4f65a822594.png)

# %%
# error will change if i am changing m
# error will change wen i am changing c

# %% [markdown]
# ![image.png](attachment:36fde7ac-e708-45a7-888a-7d68729a7cb0.png)
