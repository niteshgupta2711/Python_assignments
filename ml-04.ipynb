# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshgupta2711/Python_assignments/blob/main/ml-04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What are the key tasks involved in getting ready to work with machine learning modeling?
# 2. What are the different forms of data used in machine learning? Give a specific example for each of
# them.
# 3. Distinguish:
#
# 1. Numeric vs. categorical attributes
#
# 2. Feature selection vs. dimensionality reduction
#
# 4. Make quick notes on any two of the following:
#
# 1. The histogram
#
# 2. Use a scatter plot
#
# 3.PCA (Personal Computer Aid)
#
# 5. Why is it necessary to investigate data? Is there a discrepancy in how qualitative and quantitative
# data are explored?
#
# 6. What are the various histogram shapes? What exactly are ‘bins&#39;?
#
# 7. How do we deal with data outliers?
#
# 8. What are the various central inclination measures? Why does mean vary too much from median in
# certain data sets?
#
# 9. Describe how a scatter plot can be used to investigate bivariate relationships. Is it possible to find
# outliers using a scatter plot?
#
# 10. Describe how cross-tabs can be used to figure out how two variables are related.

# %% [markdown]
# 1. Collecting Data: As you know, machines initially learn from the data that you give them. ...
# Preparing the Data: After you have your data, you have to prepare it. ...
# Choosing a Model: ...
# Training the Model: ...
# Evaluating the Model: ...
# Parameter Tuning: ...
# Making Predictions.

# %% [markdown]
# 2. we Have Numerical Data
#  Continuos , discrete
#  * categorical Data
#    1. Nominal and Ordinal Data

# %% [markdown]
# 3. Distinguish Between Numerical And Categorical
#  + numerical Data is any Numerical Data Either Continuos OR Discrete
#  + Categorical Data is Text data within like gender, review etc, In order to deal with such data We preprocess them to be used in ML models

# %% [markdown]
# 4. While both methods are used for reducing the number of features in a dataset, there is an important difference. Feature selection is simply selecting and excluding given features without changing them. Dimensionality reduction transforms features into a lower dimension

# %% [markdown]
# * A histogram is a plot of Frequency Table of certain feature with Even Sized bins

# %% [markdown]
# *. Scatter Plot
# Scatter Plots are  point plots in X, Y ,z dimensions for Three features Scaled correctly, These plots also represent positive and negative corelation

# %% [markdown]
# * PCA
# + Personal Component Analysis
# + A staistical method to reduce the dimensions of features without losing much variance around the data (Info within)
# + This has Personal components associated with each Feature and a eigen value associated with initially
# + eigen value /summation of eigen values (imporannce of that component)

# %% [markdown]
# 5. Data analysis is broad, exploratory, and downright complex.
#
# But when we take a step back and attempt to simplify data analysis, we can quickly see it boils down to two methodologies: Qualitative data and quantitative data. These two data types are quite different, yet, they make up all of the data that will ever be analyzed.
#
# Before diving into data analytics, it’s important to understand the key differences between qualitative and quantitative data.

# %% [markdown]
# 6.A histogram is a chart that plots the distribution of a numeric variable's values as a series of bars. Each bar typically covers a range of numeric values called a bin or class; a bar's height indicates the frequency of data points with a value within the corresponding bin.

# %% [markdown]
# ## Dealing with outliers
# + Either you get rid of it, Identifying them,
# + Make data Aquisation team know about outliers and make correct from source,
# + Impute them IF It doesnt largely effect features

# %% [markdown]
# 9. MEasures of central tendency
# + mean , median, mode
# + mean Vary too much due to outliers, this is where median comes in in imputation, as they are affected by outliers to some degree

# %% [markdown]
# 9. Yes we can point otliers in scatter plot
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To describe the relationship between two categorical variables, we use a special type of table called a cross-tabulation (or "crosstab" for short). In a cross-tabulation, the categories of one variable determine the rows of the table, and the categories of the other variable determine the columns.
